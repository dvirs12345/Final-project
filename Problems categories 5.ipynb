# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 11)
excel = pd.read_excel('Classified 3.xlsx', sheet_name='Sheet1')

# %%
value_counts_for1 = excel['1'].value_counts()
print(value_counts_for1)
print("\n# of patients", excel.shape[0])
value_counts_for1.plot.bar()
plt.title("Number of people with the string")
plt.savefig("g2_1.png")
# Out:
# MS        303
# M         276
# MSTA      174
# MTA        54
# MTN        45
# MSTN       41
# STA        34
# TA         19
# S          19
# MSTATN     14
# MO         11
# MSTAO       6
# O           5
# MSO         5
# MTATN       2
# TN          1
# TATN        1
# SO          1
# Name: 1, dtype: int64
#
# # of patients 1018

# %%
value_counts_for1 = value_counts_for1[value_counts_for1>=40]
print(value_counts_for1)
# Out:
# MS      303
# M       276
# MSTA    174
# MTA      54
# MTN      45
# MSTN     41
# Name: 1, dtype: int64

# %%
value_counts_for1.plot.bar()
plt.title("Number of people with the string >=40")
plt.savefig("g2_2.png")

# %%
print(value_counts_for1.keys())
# Out:
# Index(['MS', 'M', 'MSTA', 'MTA', 'MTN', 'MSTN'], dtype='object')
